# %% [markdown]
# <a href="https://colab.research.google.com/github/kartik0920/Hands-on-Machine-learning/blob/Main/chapter_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Decision Trees

# %%
from sklearn import datasets

iris=datasets.load_iris()

x=iris["data"][:,2:]
y=iris["target"]

# %%
from sklearn.tree import DecisionTreeClassifier

tree_clf=DecisionTreeClassifier(max_depth=2)
tree_clf.fit(x,y)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn.tree import export_graphviz

export_graphviz(
    tree_clf,
    out_file=("iris_tree.dot"),
    filled=True,
    feature_names=iris.feature_names[2:],
    class_names=iris.target_names,
    rounded=True
)

# %%
# !dot -Tpng iris_tree.dot -o iris_tree.jpg

# %% [markdown]
# Regression

# %%
import numpy as np

# %%
x=np.random.rand(100,1)
y=3*x+5+np.random.rand(100,1)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y,'bo')
plt.xlabel("x")
plt.ylabel("y")
plt.title("Data for regression")
[...]
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

tree_reg=DecisionTreeRegressor(max_depth=3)
tree_reg.fit(x,y)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
export_graphviz(
    tree_reg,
    out_file=("regression_tree.dot"),
    filled=True,
    rounded=True,
    feature_names=["x"],
    class_names=["Y"]
)

# %%
# !dot -Tpng regression_tree.dot -o regress.jpg
